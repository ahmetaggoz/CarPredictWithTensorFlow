# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_csv("cars_dataset.csv")

# %%
dataFrame.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  72435.000000   72435.000000   72435.000000  72435.000000  72435.000000
# mean    2017.073666   16580.158708   23176.517057    116.953407     55.852480
# std        2.101252    9299.028754   21331.515562     64.045533     17.114391
# min     1996.000000     495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000   10175.000000    7202.500000     30.000000     47.900000
# 50%     2017.000000   14495.000000   17531.000000    145.000000     55.400000
# 75%     2019.000000   20361.000000   32449.000000    145.000000     62.800000
# max     2020.000000  145000.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  72435.000000
# mean       1.635650
# std        0.561535
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.histplot(dataFrame["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sbn.countplot(x="year", data=dataFrame)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_11856\3497904997.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.519459 -0.747270  0.244933 -0.144384   -0.028511
# price       0.519459  1.000000 -0.426925  0.353244 -0.334174    0.629251
# mileage    -0.747270 -0.426925  1.000000 -0.234098  0.179153    0.122965
# tax         0.244933  0.353244 -0.234098  1.000000 -0.423287    0.294148
# mpg        -0.144384 -0.334174  0.179153 -0.423287  1.000000   -0.282202
# engineSize -0.028511  0.629251  0.122965  0.294148 -0.282202    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_11856\625300545.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()["price"].sort_values()
# mileage      -0.426925
# mpg          -0.334174
# tax           0.353244
# year          0.519459
# engineSize    0.629251
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage", y="price", data=dataFrame)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price", ascending = False).head(20)
# Out:
#            model  year   price transmission  mileage fuelType    tax   mpg  \
# 4783          R8  2020  145000    Semi-Auto     2000   Petrol  145.0  21.1
# 2255          R8  2020  137995    Semi-Auto       70   Petrol  145.0  21.1
# 4179          R8  2019  137500    Semi-Auto       10   Petrol  150.0  21.4
# 3367          R8  2019  135000    Automatic     1000   Petrol  145.0  32.8
# 5459          R8  2020  133900    Semi-Auto      333   Petrol  145.0  21.4
# 1646          R8  2019  129000    Semi-Auto     4000   Petrol  145.0  21.4
# 4925          R8  2019  125000    Semi-Auto      500   Petrol  145.0  21.4
# 3359          R8  2019  125000    Automatic      100   Petrol  145.0  24.1
# 10468         R8  2019  125000    Automatic    13663   Petrol  150.0  21.4
# 14306   2 Series  2015  123456    Semi-Auto    33419   Diesel   20.0  68.9
# 7445          R8  2019  119995    Semi-Auto     7800   Petrol  145.0  21.4
# ...

# %%
dataFrame.sort_values("price", ascending = True).head(20)
# Out:
#           model  year  price transmission  mileage fuelType    tax   mpg  \
# 38552     Focus  2003    495       Manual   177644   Petrol  200.0  41.5
# 35671    Mondeo  2005    675       Manual    97000   Diesel  205.0  48.7
# 38353     Focus  2005    675       Manual   121000   Petrol  235.0  39.8
# 38260    Mondeo  2005    675       Manual   108000   Petrol  260.0  36.2
# 38153    Fiesta  2008    694       Manual    82020   Petrol  145.0  47.1
# 38885     Focus  2005    795       Manual    71214   Petrol  200.0  42.1
# 38697        KA  2008    795       Manual    76000   Petrol  205.0  43.5
# 60997   Avensis  2003    850       Manual   167054   Diesel  205.0  48.7
# 38820        KA  2008    850       Manual    77000   Petrol  195.0  43.5
# 35816    Mondeo  2002    895       Manual   136784   Petrol  300.0  36.2
# 52736    Beetle  2001    899    Automatic        1   Petrol  325.0  29.7
# 54859   Corolla  2001    899    Automatic    76000   Petrol  300.0  35.3
# ...

# %%
len(dataFrame)
# Out:
# 72435

# %%
len(dataFrame) * 0.01
# Out:
# 724.35

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price", ascending = False).iloc[724:]

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  71711.000000  71711.000000   71711.000000  71711.000000  71711.000000
# mean    2017.054246  16127.731785   23348.122296    116.583579     56.058807
# std        2.100922   8066.757562   21360.296291     64.077240     16.968789
# min     1996.000000    495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000  10000.000000    7400.000000     30.000000     47.900000
# 50%     2017.000000  14390.000000   17790.000000    145.000000     55.400000
# 75%     2019.000000  19998.000000   32656.500000    145.000000     62.800000
# max     2020.000000  50786.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  71711.000000
# mean       1.620192
# std        0.538497
# min        0.000000
# 25%        1.200000
# 50%        1.500000
# 75%        2.000000
# max        6.300000

# %%
plt.figure(figsize=(7,5))
sbn.histplot(yuzdeDoksanDokuzDf["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  72435.000000   72435.000000   72435.000000  72435.000000  72435.000000
# mean    2017.073666   16580.158708   23176.517057    116.953407     55.852480
# std        2.101252    9299.028754   21331.515562     64.045533     17.114391
# min     1996.000000     495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000   10175.000000    7202.500000     30.000000     47.900000
# 50%     2017.000000   14495.000000   17531.000000    145.000000     55.400000
# 75%     2019.000000   20361.000000   32449.000000    145.000000     62.800000
# max     2020.000000  145000.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  72435.000000
# mean       1.635650
# std        0.561535
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_11856\2092793654.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataFrame.groupby("year").mean()["price"]
# year
# 1996     4497.500000
# 1997     4300.000000
# 1998     7909.500000
# 1999     3027.000000
# 2000     1872.166667
# 2001     3884.125000
# 2002     3134.647059
# 2003     3564.272727
# 2004     5086.156250
# 2005     2997.250000
# 2006     3953.910448
# 2007     3719.149123
# 2008     3982.713376
# 2009     4512.820628
# 2010     5297.722222
# 2011     6758.385093
# 2012     7785.716667
# 2013     8583.889894
# 2014     9914.478546
# 2015    11564.780623
# 2016    13268.731827
# 2017    14139.380723
# 2018    15785.243497
# 2019    23369.525774
# 2020    28433.390832
# Name: price, dtype: float64

# %%
yuzdeDoksanDokuzDf.groupby("year").mean()["price"]
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_11856\3963167876.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yuzdeDoksanDokuzDf.groupby("year").mean()["price"]
# year
# 1996     4497.500000
# 1997     4300.000000
# 1998     7909.500000
# 1999     3027.000000
# 2000     1872.166667
# 2001     3884.125000
# 2002     3134.647059
# 2003     3564.272727
# 2004     5086.156250
# 2005     2997.250000
# 2006     3953.910448
# 2007     3719.149123
# 2008     3982.713376
# 2009     4512.820628
# 2010     5297.722222
# 2011     6758.385093
# 2012     7785.716667
# 2013     8560.617203
# 2014     9868.351803
# 2015    11529.714926
# 2016    13240.773127
# 2017    14044.151689
# 2018    15515.842273
# 2019    22491.661827
# 2020    26429.160395
# Name: price, dtype: float64

# %%
dataFrame = yuzdeDoksanDokuzDf

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  71711.000000  71711.000000   71711.000000  71711.000000  71711.000000
# mean    2017.054246  16127.731785   23348.122296    116.583579     56.058807
# std        2.100922   8066.757562   21360.296291     64.077240     16.968789
# min     1996.000000    495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000  10000.000000    7400.000000     30.000000     47.900000
# 50%     2017.000000  14390.000000   17790.000000    145.000000     55.400000
# 75%     2019.000000  19998.000000   32656.500000    145.000000     62.800000
# max     2020.000000  50786.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  71711.000000
# mean       1.620192
# std        0.538497
# min        0.000000
# 25%        1.200000
# 50%        1.500000
# 75%        2.000000
# max        6.300000

# %%
dataFrame.head()
# Out:
#       model  year  price transmission  mileage fuelType    tax   mpg  \
# 2861     Q8  2019  50786    Automatic     4278   Diesel  145.0  33.6
# 4682     Q8  2019  50576    Automatic     4968   Diesel  145.0  33.6
# 17478    X5  2018  50495    Semi-Auto    31855   Petrol  145.0  25.4
# 14971    X5  2019  50480    Automatic     6215   Diesel  145.0  37.7
# 516      Q7  2019  50414    Semi-Auto     4236   Diesel  145.0  33.2
#
#        engineSize  Make
# 2861          3.0  audi
# 4682          3.0  audi
# 17478         4.4   BMW
# 14971         3.0   BMW
# 516           3.0  audi

# %%
dataFrame = dataFrame.drop(["transmission","model", "fuelType", "Make"], axis=1)

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price", axis=1).values

# %%
y
# Out:
# array([50786, 50576, 50495, ...,   675,   675,   495], dtype=int64)

# %%
x
# Out:
# array([[2.01900e+03, 4.27800e+03, 1.45000e+02, 3.36000e+01, 3.00000e+00],
#        [2.01900e+03, 4.96800e+03, 1.45000e+02, 3.36000e+01, 3.00000e+00],
#        [2.01800e+03, 3.18550e+04, 1.45000e+02, 2.54000e+01, 4.40000e+00],
#        ...,
#        [2.00500e+03, 1.08000e+05, 2.60000e+02, 3.62000e+01, 1.80000e+00],
#        [2.00500e+03, 1.21000e+05, 2.35000e+02, 3.98000e+01, 2.00000e+00],
#        [2.00300e+03, 1.77644e+05, 2.00000e+02, 4.15000e+01, 1.60000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
len(x_train)
# Out:
# 50197

# %%
len(x_test)
# Out:
# 21514

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (50197, 5)

# %%
model = Sequential()

model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test, y_test), batch_size=350, epochs=400)
# Out:
# Epoch 1/400
# 144/144 [==============================] - 1s 4ms/step - loss: 326792160.0000 - val_loss: 320608032.0000
# Epoch 2/400
# 144/144 [==============================] - 0s 2ms/step - loss: 323113344.0000 - val_loss: 309747552.0000
# Epoch 3/400
# 144/144 [==============================] - 0s 2ms/step - loss: 287459488.0000 - val_loss: 236609104.0000
# Epoch 4/400
# 144/144 [==============================] - 0s 2ms/step - loss: 167348512.0000 - val_loss: 91378784.0000
# Epoch 5/400
# 144/144 [==============================] - 0s 2ms/step - loss: 65509316.0000 - val_loss: 54906404.0000
# Epoch 6/400
# 144/144 [==============================] - 0s 2ms/step - loss: 54857380.0000 - val_loss: 53925656.0000
# Epoch 7/400
# 144/144 [==============================] - 0s 2ms/step - loss: 53942392.0000 - val_loss: 52997768.0000
# Epoch 8/400
# 144/144 [==============================] - 0s 2ms/step - loss: 52801504.0000 - val_loss: 51605668.0000
# Epoch 9/400
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  326792160.0  320608032.0
# 1  323113344.0  309747552.0
# 2  287459488.0  236609104.0
# 3  167348512.0   91378784.0
# 4   65509316.0   54906404.0

# %%
kayipVerisi.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)

# %%
tahminDizisi
# Out:
# array([[16890.312],
#        [ 9832.674],
#        [26503.457],
#        ...,
#        [15055.82 ],
#        [24610.094],
#        [19374.152]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)
# Out:
# 2510.5163658105207

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  71711.000000  71711.000000   71711.000000  71711.000000  71711.000000
# mean    2017.054246  16127.731785   23348.122296    116.583579     56.058807
# std        2.100922   8066.757562   21360.296291     64.077240     16.968789
# min     1996.000000    495.000000       1.000000      0.000000      0.300000
# 25%     2016.000000  10000.000000    7400.000000     30.000000     47.900000
# 50%     2017.000000  14390.000000   17790.000000    145.000000     55.400000
# 75%     2019.000000  19998.000000   32656.500000    145.000000     62.800000
# max     2020.000000  50786.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  71711.000000
# mean       1.620192
# std        0.538497
# min        0.000000
# 25%        1.200000
# 50%        1.500000
# 75%        2.000000
# max        6.300000

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test, y_test, "g-*")
